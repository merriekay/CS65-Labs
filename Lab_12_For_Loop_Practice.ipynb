# %% [markdown]
# # Lab #12: For Loops
#
# In this lab, you will get practice writing `for` loops. You'll use them to looop through lists with and without the `range()` function.

# %% [markdown]
# ## Exercise #1:
# Write a for loop that displays the indices of the days that it rained using `rainfall`. The output might look like this:
#
# `It rained on Day 1`
#
# `It rained on Day 2`
#
# `It rained on Day 4`
#
# `It rained on Day 5`
#
# `It rained on Day 6`

# %%
rainfall = [0.0, 0.3, 0.71, 0.0, 0.32, 1.1, 0.4]

# %% [markdown]
# ## Exercise #2:
#
# The following for loop attempts to say "Hi" to all of the Computer Science professors at Drake, but it has an error. Find the error and fix it so that this code works as intended!
# > Hint: There are two possible solutions to this one, for a challenge, see if you can find both!

# %%
drake_cs_profs = ["Tim","Eric","Adam","Chris","Meredith","Alimoor"]

for i in drake_cs_profs:
    print("Hi", drake_cs_profs[i])

# %% [markdown]
# ## Challenge Exercise #3:
# In mathematics, the notation $n!$ represents the factorial of the positive integer $n$. The _factorial_ is the product of all the integers from 1 to $n$. For example $$7! = 1*2*3*4*5*6*7 = 5040$$ and $$4! = 1*2*3*4 = 24.$$ Create a new file called `mathfunctions.py` and write a function called `factorial()` that uses a `for` loop to find the factorial of a number. It should work like this:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When you are finished, submit your solution to the __Lab 12: Factorial__ assignment on codePost where it will be unit tested. You _must_ submit a .py file with the exact name `mathfunctions.py` and your function has to have the exact name `factorial()`.
